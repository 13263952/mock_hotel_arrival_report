# %%
import pandas as pd
from tabulate import tabulate
import datetime

# Read data from the TXT file
df = pd.read_csv('guest_list.txt', delimiter='\t')

# Function to extract the first letter of the last name
def extract_last_name_first_letter(name):
    last_name = name.split()[-1]
    return last_name[0].upper()

# Sort the DataFrame by last name
df['Last Name'] = df['Guest Name'].apply(lambda x: x.split()[-1])
df.sort_values(by='Last Name', inplace=True)

# Group the DataFrame by the first letter of the last name
groups = df.groupby(df['Last Name'].apply(extract_last_name_first_letter))

# Generate the tab layout for each group
tab_layout = []
for letter, group in groups:
    tab_layout.append([letter, ', '.join(group['Guest Name'])])

# Print the tab layout
print(tabulate(tab_layout, headers=['Letter', 'Guest Names'], tablefmt='grid'))

# Save the tab layout to a TXT file with the specified name format

# Get the current date in the specified format
date_today = datetime.datetime.today().strftime('%b-%d-%y')

# Define the filename based on the date
filename = f'last_name_alphabetized_{date_today}.txt'

# Save the tab layout to the TXT file
with open(filename, 'w') as file:
    file.write(tabulate(tab_layout, headers=['Letter', 'Guest Names'], tablefmt='grid'))
# Out:
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Letter   | Guest Names                                                                                                                                                                                                                                                  |
# +==========+==============================================================================================================================================================================================================================================================+
# | A        | Isabella Adams, Mohammed Adams, Sofia Adams, Ananya Adams, Amelia Adams, Nathan Adams, Hiroshi Adams, Emily Adams, Amelia Adams, Mohammed Adams, Yusuke Adams, Arjun Adams                                                                                   |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | B        | Nathan Brown, Samantha Brown, Aarav Brown, Ella Brown, John Brown, Emily Brown, Yuki Brown, Mohammed Brown, Maria Brown, Alexandre Brown                                                                                                                     |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | C        | Emily Clark, Mohammed Clark, Yusuke Clark, Alexandre Clark, Mohammed Clark, Ananya Clark, Luis Clark, Emily Clark, Ananya Clark, Isabella Clark, Arjun Clark, Liam Clark, Emily Clark                                                                        |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | D        | Liam Davis, Arjun Davis, Samantha Davis, Ananya Davis, Yusuke Davis, Mohammed Davis, Arjun Davis, Natasha Davis, Ananya Davis, Nathan Davis, Isabella Davis, Yuki Davis, Mohammed Davis, Liam Davis, Alexandre Davis                                         |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | E        | Mohammed Evans, Arjun Evans, Aarav Evans, Alexandre Evans, Sofia Evans, Liam Evans, Yusuke Evans, Maria Evans, Ella Evans, Ella Evans, Arjun Evans, Yusuke Evans, Yuki Evans, Hiroshi Evans                                                                  |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | F        | Yusuke Frank, Alexandre Frank, Aarav Frank, Amelia Frank                                                                                                                                                                                                     |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | G        | Amelia Gomez, Nathan Gomez, Emily Gomez, Sofia Gomez, Alexandre Gomez, Sofia Gomez, Alexandre Gomez, Yusuke Gomez, Alexandre Gomez, Natasha Gomez, John Gomez, Alexandre Gomez, Luis Gomez                                                                   |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | H        | Nathan Hall, Ella Hall, Mohammed Hall, Yusuke Hall, Ella Hall, Amelia Hall, Amelia Hall, Liam Hall, John Hall, Ananya Hall, Isabella Hall, Mohammed Hall, Luis Hall                                                                                          |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | I        | Ananya Irwin, Ella Irwin, Samantha Irwin, Mohammed Irwin, Yuki Irwin, Yusuke Irwin, Liam Irwin, Natasha Irwin, Luis Irwin                                                                                                                                    |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | J        | Alexandre Johnson, Luis Johnson, Amelia Johnson, Hiroshi Johnson, Nathan Johnson, John Johnson, Nathan Johnson, Sofia Johnson, Sofia Johnson, Isabella Johnson                                                                                               |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | K        | Hiroshi Klein, Aarav Klein, John Klein, Hiroshi Klein, John Klein, Alexandre Klein, Natasha Klein, Liam Klein, Natasha Klein, Yusuke Klein, Mohammed Klein                                                                                                   |
# +----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#